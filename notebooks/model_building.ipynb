# %%
import pandas as pd
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.impute import SimpleImputer

# Load the merged dataset
data = pd.read_csv('merged_data_updated.csv')

# Check for missing values
missing_values = data.isnull().sum()
print("Missing values in each column:\n", missing_values[missing_values > 0])

# Identify columns with all missing values
all_missing_columns = missing_values[missing_values == len(data)].index
print("Columns with all missing values:\n", all_missing_columns)

# Drop columns with all missing values
data_dropped = data.drop(columns=all_missing_columns)

# Separate numeric and non-numeric columns
numeric_cols = data_dropped.select_dtypes(include=['number']).columns
non_numeric_cols = data_dropped.select_dtypes(exclude=['number']).columns

# Handle missing values for numeric columns
imputer_numeric = SimpleImputer(strategy='mean')
data_numeric_imputed = pd.DataFrame(imputer_numeric.fit_transform(data_dropped[numeric_cols]), columns=numeric_cols)

# Handle missing values for non-numeric columns
imputer_non_numeric = SimpleImputer(strategy='most_frequent')
data_non_numeric_imputed = pd.DataFrame(imputer_non_numeric.fit_transform(data_dropped[non_numeric_cols]), columns=non_numeric_cols)

# Combine the imputed data
data_imputed = pd.concat([data_numeric_imputed, data_non_numeric_imputed], axis=1)

# Check if ProductCategory is present and print the columns
print("Columns after imputation:\n", data_imputed.columns)

# One-hot encode the 'ProductCategory' column if present
if 'ProductCategory' in data_imputed.columns:
    data_imputed = pd.get_dummies(data_imputed, columns=['ProductCategory'], drop_first=True)

# Feature selection and preprocessing
features = data_imputed.drop(columns=['Year', 'Month', 'Sales(In ThousandDollars)'], errors='ignore')
target = data_imputed['Sales(In ThousandDollars)']

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# Gradient Boosting Regressor
gbr = GradientBoostingRegressor()
gbr.fit(X_train, y_train)
gbr_predictions = gbr.predict(X_test)
gbr_mae = mean_absolute_error(y_test, gbr_predictions)
print(f'Gradient Boosting Regressor MAE: {gbr_mae}')

# Generate the date sequence for 36 years from the merged data
date_sequence = data_imputed[['Year', 'Month']].drop_duplicates()
date_sequence['Year'] = date_sequence['Year'].astype(int)
date_sequence['Month'] = date_sequence['Month'].astype(int)
date_sequence['Date'] = pd.to_datetime(date_sequence['Year'].astype(str) + '-' + date_sequence['Month'].astype(str).str.zfill(2))
date_sequence = date_sequence.sort_values('Date').reset_index(drop=True)
date_sequence['Year_Sequential'] = range(1, len(date_sequence) + 1)

# Prepare the Kaggle submission DataFrame
kaggle_submission = pd.DataFrame({'Year': range(1, 37)})
predictions = []

# Loop over each year in the Kaggle submission and make predictions
for seq_year in kaggle_submission['Year']:
    if seq_year in date_sequence['Year_Sequential'].values:
        date = pd.Timestamp(date_sequence[date_sequence['Year_Sequential'] == seq_year]['Date'].values[0])
        feature_row = data_imputed[(data_imputed['Year'] == date.year) & (data_imputed['Month'] == date.month)]

        # Make sure the feature_row is non-empty and has the same columns as the training data
        if not feature_row.empty:
            feature_row = feature_row.drop(columns=['Year', 'Month', 'Sales(In ThousandDollars)'])

            # Debugging: Print the feature row before prediction
            print(f'Feature row for Sequential Year {seq_year} ({date.strftime("%m/%Y")}):\n', feature_row)

            gbr_prediction = gbr.predict(feature_row)
            predictions.append(gbr_prediction.mean())  # Use the mean if there are multiple rows
        else:
            print(f'No data available for Sequential Year {seq_year}')
            predictions.append(0)  # Default to 0 if no data is available for the year
    else:
        print(f'Sequential Year {seq_year} not found in date sequence')
        predictions.append(0)  # Default to 0 if the sequential year is not found

# Fill in the Sales(In ThousandDollars) column with predictions
kaggle_submission['Sales(In ThousandDollars)'] = predictions

# Save the updated submission file
submission_path = 'submission_updated.csv'
kaggle_submission.to_csv(submission_path, index=False)

# Confirm the file is saved
print(f'Saved the updated submission file to {submission_path}')
# Out:
# Missing values in each column:
#  Monthly Nominal GDP Index (inMillion$)         273
# Monthly Real GDP Index (inMillion$)            273
# CPI                                            273
# unemployment rate                              273
# CommercialBankInterestRateonCreditCardPlans    273
#                                               ...
# Wind (km/h) low                                669
# Wind (km/h) avg                                669
# Wind (km/h) high                               669
# Precip. (mm) sum                               669
# WeatherEvent                                   669
# Length: 63, dtype: int64
# Columns with all missing values:
#  Index(['Day', 'Temp high (°C)', 'Temp avg (°C)', 'Temp low (°C)',
#        'Dew Point high (°C)', 'Dew Point avg (°C)', 'Dew Point low (°C)',
#        'Humidity (%) high', 'Humidity (%) avg', 'Humidity (%) low',
#        'Sea Level Press. (hPa) high', 'Sea Level Press. (hPa) avg',
#        'Sea Level Press. (hPa) low', 'Visibility (km) high',
#        'Visibility (km) avg', 'Visibility (km) low', 'Wind (km/h) low',
#        'Wind (km/h) avg', 'Wind (km/h) high', 'Precip. (mm) sum',
#        'WeatherEvent'],
#       dtype='object')
# Columns after imputation:
#  Index(['Year', 'Month', 'Sales(In ThousandDollars)',
#        'Monthly Nominal GDP Index (inMillion$)',
#        'Monthly Real GDP Index (inMillion$)', 'CPI', 'unemployment rate',
#        'CommercialBankInterestRateonCreditCardPlans',
#        'Finance Rate on Personal Loans at Commercial Banks, 24 Month Loan',
#        'Earnings or wages  in dollars per hour',
#        'AdvertisingExpenses (in Thousand Dollars)',
#        'Cotton Monthly Price - US cents per Pound(lbs)', 'Change(in%)',
#        'Average upland planted(million acres)',
#        'Average upland harvested(million acres)', 'yieldperharvested acre',
#        'Production (in  480-lb netweright in million bales)',
#        'Mill use  (in  480-lb netweright in million bales)', 'Exports',
#        'ProductCategory_MenClothing', 'ProductCategory_OtherClothing',
#        'ProductCategory_WomenClothing', 'PartyInPower_Democrats',
#        'Event_'Christmas Day' observed', 'Event_'Independence Day' observed',
#        'Event_'New Year's Day' observed', 'Event_Christmas Day',
#        'Event_Christmas Eve', 'Event_Columbus Day (Most regions)',
#        'Event_Day After Christmas Day', 'Event_Easter Sunday',
#        'Event_Election Day', 'Event_Father's Day', 'Event_Halloween',
#        'Event_Independence Day', 'Event_Labor Day',
#        'Event_Martin Luther King Jr. Day', 'Event_Memorial Day',
#        'Event_Mother's Day', 'Event_New Year's Day', 'Event_New Year's Eve',
#        'Event_Presidents' Day', 'Event_Thanksgiving Day',
#        'Event_Thomas Jefferson's Birthday', 'Event_Valentine's Day',
#        'Event_Veterans Day', 'DayCategory_Event',
#        'DayCategory_Federal Holiday'],
#       dtype='object')
# Gradient Boosting Regressor MAE: 137.29471586821128
# Feature row for Sequential Year 1 (01/2009):
#      Monthly Nominal GDP Index (inMillion$)  \
# 0                             14421.752895
# 1                             14421.752895
# 2                             14389.200466
# 3                             14389.200466
# 4                             14340.701639
# ..                                     ...
# 67                            14596.605447
# 68                            14590.432252
# 69                            14590.432252
# 70                            14512.495301
# 71                            14512.495301
#
#     Monthly Real GDP Index (inMillion$)      CPI  unemployment rate  \
# 0                          14407.053343  233.402                7.8
# 1                          14407.053343  233.402                7.8
# 2                          14366.176571  234.663                8.3
# 3                          14366.176571  234.663                8.3
# 4                          14351.786822  235.067                8.7
# ..                                  ...      ...                ...
# 67                         14595.393094  238.380               10.0
# 68                         14559.410173  238.777                9.9
# 69                         14559.410173  238.777                9.9
# 70                         14471.040844  238.427                9.9
# 71                         14471.040844  238.427                9.9
#
#     CommercialBankInterestRateonCreditCardPlans  \
# 0                                         12.03
# 1                                         12.03
# 2                                         12.97
# 3                                         12.97
# 4                                         12.97
# ..                                          ...
# 67                                        13.71
# 68                                        13.60
# 69                                        13.60
# 70                                        13.60
# 71                                        13.60
#
#     Finance Rate on Personal Loans at Commercial Banks, 24 Month Loan  \
# 0                                               11.44
# 1                                               11.44
# 2                                               11.05
# 3                                               11.05
# 4                                               11.05
# ..                                                ...
# 67                                              10.89
# 68                                              11.20
# 69                                              11.20
# 70                                              11.20
# 71                                              11.20
#
#     Earnings or wages  in dollars per hour  \
# 0                                    22.05
# 1                                    22.05
# 2                                    22.22
# 3                                    22.22
# 4                                    22.22
# ..                                     ...
# 67                                   22.27
# 68                                   22.44
# 69                                   22.44
# 70                                   22.38
# 71                                   22.38
#
#     AdvertisingExpenses (in Thousand Dollars)  \
# 0                                       137.0
# 1                                       137.0
# 2                                       200.0
# 3                                       200.0
# 4                                       200.0
# ..                                        ...
# 67                                      200.0
# 68                                      200.0
# 69                                      200.0
# 70                                      200.0
# 71                                      200.0
#
#     Cotton Monthly Price - US cents per Pound(lbs)  Change(in%)  ...  \
# 0                                            57.70         4.02  ...
# 1                                            57.70         4.02  ...
# 2                                            55.21        -4.32  ...
# 3                                            55.21        -4.32  ...
# 4                                            51.50        -6.72  ...
# ..                                             ...          ...  ...
# 67                                           66.82         4.29  ...
# 68                                           71.78         7.42  ...
# 69                                           71.78         7.42  ...
# 70                                           76.78         6.97  ...
# 71                                           76.78         6.97  ...
#
#     Event_Mother's Day  Event_New Year's Day  Event_New Year's Eve  \
# 0                False                  True                 False
# 1                False                 False                 False
# 2                False                  True                 False
# 3                False                 False                 False
# 4                False                  True                 False
# ..                 ...                   ...                   ...
# 67               False                 False                 False
# 68               False                  True                 False
# 69               False                 False                 False
# 70               False                  True                 False
# 71               False                 False                 False
#
#     Event_Presidents' Day  Event_Thanksgiving Day  \
# 0                   False                   False
# 1                   False                   False
# 2                   False                   False
# 3                   False                   False
# 4                   False                   False
# ..                    ...                     ...
# 67                  False                   False
# 68                  False                   False
# 69                  False                   False
# 70                  False                   False
# 71                  False                   False
#
#     Event_Thomas Jefferson's Birthday Event_Valentine's Day  \
# 0                               False                 False
# 1                               False                 False
# 2                               False                 False
# 3                               False                 False
# 4                               False                 False
# ..                                ...                   ...
# 67                              False                 False
# 68                              False                 False
# 69                              False                 False
# 70                              False                 False
# 71                              False                 False
#
#    Event_Veterans Day DayCategory_Event DayCategory_Federal Holiday
# 0               False             False                        True
# 1               False             False                        True
# 2               False             False                        True
# 3               False             False                        True
# 4               False             False                        True
# ..                ...               ...                         ...
# 67              False             False                        True
# 68              False             False                        True
# 69              False             False                        True
# 70              False             False                        True
# 71              False             False                        True
#
# [72 rows x 45 columns]
# Feature row for Sequential Year 2 (02/2009):
#      Monthly Nominal GDP Index (inMillion$)  \
# 72                            15604.628182
# 73                            15604.628182
# 74                            15604.628182
# 75                            15604.628182
# 76                            15604.628182
# 77                            15604.628182
#
#     Monthly Real GDP Index (inMillion$)         CPI  unemployment rate  \
# 72                         15066.834087  247.476712           8.600758
# 73                         15066.834087  247.476712           8.600758
# 74                         15066.834087  247.476712           8.600758
# 75                         15066.834087  247.476712           8.600758
# 76                         15066.834087  247.476712           8.600758
# 77                         15066.834087  247.476712           8.600758
#
#     CommercialBankInterestRateonCreditCardPlans  \
# 72                                    12.718409
# 73                                    12.718409
# 74                                    12.718409
# 75                                    12.718409
# 76                                    12.718409
# 77                                    12.718409
#
#     Finance Rate on Personal Loans at Commercial Banks, 24 Month Loan  \
# 72                                          10.764091
# 73                                          10.764091
# 74                                          10.764091
# 75                                          10.764091
# 76                                          10.764091
# 77                                          10.764091
#
#     Earnings or wages  in dollars per hour  \
# 72                               23.084015
# 73                               23.084015
# 74                               23.084015
# 75                               23.084015
# 76                               23.084015
# 77                               23.084015
#
#     AdvertisingExpenses (in Thousand Dollars)  \
# 72                                  197.94697
# 73                                  197.94697
# 74                                  197.94697
# 75                                  197.94697
# 76                                  197.94697
# 77                                  197.94697
#
#     Cotton Monthly Price - US cents per Pound(lbs)  Change(in%)  ...  \
# 72                                       99.121667     0.907348  ...
# 73                                       99.121667     0.907348  ...
# 74                                       99.121667     0.907348  ...
# 75                                       99.121667     0.907348  ...
# 76                                       99.121667     0.907348  ...
# 77                                       99.121667     0.907348  ...
#
#     Event_Mother's Day  Event_New Year's Day  Event_New Year's Eve  \
# 72               False                 False                 False
# 73               False                 False                 False
# 74               False                 False                 False
# 75               False                 False                 False
# 76               False                 False                 False
# 77               False                 False                 False
#
#     Event_Presidents' Day  Event_Thanksgiving Day  \
# 72                  False                   False
# 73                   True                   False
# 74                  False                   False
# 75                   True                   False
# 76                  False                   False
# 77                   True                   False
#
#     Event_Thomas Jefferson's Birthday Event_Valentine's Day  \
# 72                              False                  True
# 73                              False                 False
# 74                              False                  True
# 75                              False                 False
# 76                              False                  True
# 77                              False                 False
#
#    Event_Veterans Day DayCategory_Event DayCategory_Federal Holiday
# 72              False              True                       False
# 73              False             False                        True
# 74              False              True                       False
# 75              False             False                        True
# 76              False              True                       False
# 77              False             False                        True
#
# [6 rows x 45 columns]
# Feature row for Sequential Year 3 (03/2009):
#      Monthly Nominal GDP Index (inMillion$)  \
# 78                            15604.628182
# 79                            15604.628182
# 80                            15604.628182
#
#     Monthly Real GDP Index (inMillion$)         CPI  unemployment rate  \
# 78                         15066.834087  247.476712           8.600758
# 79                         15066.834087  247.476712           8.600758
# 80                         15066.834087  247.476712           8.600758
#
#     CommercialBankInterestRateonCreditCardPlans  \
# 78                                    12.718409
# 79                                    12.718409
# 80                                    12.718409
#
#     Finance Rate on Personal Loans at Commercial Banks, 24 Month Loan  \
# 78                                          10.764091
# 79                                          10.764091
# 80                                          10.764091
#
#     Earnings or wages  in dollars per hour  \
# 78                               23.084015
# 79                               23.084015
# 80                               23.084015
#
#     AdvertisingExpenses (in Thousand Dollars)  \
# 78                                  197.94697
# 79                                  197.94697
# 80                                  197.94697
#
#     Cotton Monthly Price - US cents per Pound(lbs)  Change(in%)  ...  \
# 78                                       99.121667     0.907348  ...
# 79                                       99.121667     0.907348  ...
# 80                                       99.121667     0.907348  ...
#
#     Event_Mother's Day  Event_New Year's Day  Event_New Year's Eve  \
# 78               False                 False                 False
# 79               False                 False                 False
# 80               False                 False                 False
#
#     Event_Presidents' Day  Event_Thanksgiving Day  \
# 78                  False                   False
# 79                  False                   False
# 80                  False                   False
#
#     Event_Thomas Jefferson's Birthday Event_Valentine's Day  \
# 78                              False                 False
# 79                              False                 False
# 80                              False                 False
#
#    Event_Veterans Day DayCategory_Event DayCategory_Federal Holiday
# 78              False             False                        True
# 79              False             False                        True
# 80              False             False                        True
#
# [3 rows x 45 columns]
# Feature row for Sequential Year 4 (04/2009):
#      Monthly Nominal GDP Index (inMillion$)  \
# 81                            15604.628182
# 82                            15604.628182
# 83                            15604.628182
#
#     Monthly Real GDP Index (inMillion$)         CPI  unemployment rate  \
# 81                         15066.834087  247.476712           8.600758
# 82                         15066.834087  247.476712           8.600758
# 83                         15066.834087  247.476712           8.600758
#
#     CommercialBankInterestRateonCreditCardPlans  \
# 81                                    12.718409
# 82                                    12.718409
# 83                                    12.718409
#
#     Finance Rate on Personal Loans at Commercial Banks, 24 Month Loan  \
# 81                                          10.764091
# 82                                          10.764091
# 83                                          10.764091
#
#     Earnings or wages  in dollars per hour  \
# 81                               23.084015
# 82                               23.084015
# 83                               23.084015
#
#     AdvertisingExpenses (in Thousand Dollars)  \
# 81                                  197.94697
# 82                                  197.94697
# 83                                  197.94697
#
#     Cotton Monthly Price - US cents per Pound(lbs)  Change(in%)  ...  \
# 81                                       99.121667     0.907348  ...
# 82                                       99.121667     0.907348  ...
# 83                                       99.121667     0.907348  ...
#
#     Event_Mother's Day  Event_New Year's Day  Event_New Year's Eve  \
# 81               False                 False                 False
# 82               False                 False                 False
# 83               False                 False                 False
#
#     Event_Presidents' Day  Event_Thanksgiving Day  \
# 81                  False                   False
# 82                  False                   False
# 83                  False                   False
#
#     Event_Thomas Jefferson's Birthday Event_Valentine's Day  \
# 81                              False                 False
# 82                              False                 False
# 83                              False                 False
#
#    Event_Veterans Day DayCategory_Event DayCategory_Federal Holiday
# 81              False              True                       False
# 82              False              True                       False
# 83              False              True                       False
#
# [3 rows x 45 columns]
# Feature row for Sequential Year 5 (05/2009):
#      Monthly Nominal GDP Index (inMillion$)  \
# 84                            15604.628182
# 85                            15604.628182
# 86                            15604.628182
# 87                            15604.628182
# 88                            15604.628182
# 89                            15604.628182
#
#     Monthly Real GDP Index (inMillion$)         CPI  unemployment rate  \
# 84                         15066.834087  247.476712           8.600758
# 85                         15066.834087  247.476712           8.600758
# 86                         15066.834087  247.476712           8.600758
# 87                         15066.834087  247.476712           8.600758
# 88                         15066.834087  247.476712           8.600758
# 89                         15066.834087  247.476712           8.600758
#
#     CommercialBankInterestRateonCreditCardPlans  \
# 84                                    12.718409
# 85                                    12.718409
# 86                                    12.718409
# 87                                    12.718409
# 88                                    12.718409
# 89                                    12.718409
#
#     Finance Rate on Personal Loans at Commercial Banks, 24 Month Loan  \
# 84                                          10.764091
# 85                                          10.764091
# 86                                          10.764091
# 87                                          10.764091
# 88                                          10.764091
# 89                                          10.764091
#
#     Earnings or wages  in dollars per hour  \
# 84                               23.084015
# 85                               23.084015
# 86                               23.084015
# 87                               23.084015
# 88                               23.084015
# 89                               23.084015
#
#     AdvertisingExpenses (in Thousand Dollars)  \
# 84                                  197.94697
# 85                                  197.94697
# 86                                  197.94697
# 87                                  197.94697
# 88                                  197.94697
# 89                                  197.94697
#
#     Cotton Monthly Price - US cents per Pound(lbs)  Change(in%)  ...  \
# 84                                       99.121667     0.907348  ...
# 85                                       99.121667     0.907348  ...
# 86                                       99.121667     0.907348  ...
# 87                                       99.121667     0.907348  ...
# 88                                       99.121667     0.907348  ...
# 89                                       99.121667     0.907348  ...
#
#     Event_Mother's Day  Event_New Year's Day  Event_New Year's Eve  \
# 84                True                 False                 False
# 85               False                 False                 False
# 86                True                 False                 False
# 87               False                 False                 False
# 88                True                 False                 False
# 89               False                 False                 False
#
#     Event_Presidents' Day  Event_Thanksgiving Day  \
# 84                  False                   False
# 85                  False                   False
# 86                  False                   False
# 87                  False                   False
# 88                  False                   False
# 89                  False                   False
#
#     Event_Thomas Jefferson's Birthday Event_Valentine's Day  \
# 84                              False                 False
# 85                              False                 False
# 86                              False                 False
# 87                              False                 False
# 88                              False                 False
# 89                              False                 False
#
#    Event_Veterans Day DayCategory_Event DayCategory_Federal Holiday
# 84              False              True                       False
# 85              False             False                        True
# 86              False              True                       False
# 87              False             False                        True
# 88              False              True                       False
# 89              False             False                        True
#
# [6 rows x 45 columns]
# Feature row for Sequential Year 6 (06/2009):
#      Monthly Nominal GDP Index (inMillion$)  \
# 90                            15604.628182
# 91                            15604.628182
# 92                            15604.628182
#
#     Monthly Real GDP Index (inMillion$)         CPI  unemployment rate  \
# 90                         15066.834087  247.476712           8.600758
# 91                         15066.834087  247.476712           8.600758
# 92                         15066.834087  247.476712           8.600758
#
#     CommercialBankInterestRateonCreditCardPlans  \
# 90                                    12.718409
# 91                                    12.718409
# 92                                    12.718409
#
#     Finance Rate on Personal Loans at Commercial Banks, 24 Month Loan  \
# 90                                          10.764091
# 91                                          10.764091
# 92                                          10.764091
#
#     Earnings or wages  in dollars per hour  \
# 90                               23.084015
# 91                               23.084015
# 92                               23.084015
#
#     AdvertisingExpenses (in Thousand Dollars)  \
# 90                                  197.94697
# 91                                  197.94697
# 92                                  197.94697
#
#     Cotton Monthly Price - US cents per Pound(lbs)  Change(in%)  ...  \
# 90                                       99.121667     0.907348  ...
# 91                                       99.121667     0.907348  ...
# 92                                       99.121667     0.907348  ...
#
#     Event_Mother's Day  Event_New Year's Day  Event_New Year's Eve  \
# 90               False                 False                 False
# 91               False                 False                 False
# 92               False                 False                 False
#
#     Event_Presidents' Day  Event_Thanksgiving Day  \
# 90                  False                   False
# 91                  False                   False
# 92                  False                   False
#
#     Event_Thomas Jefferson's Birthday Event_Valentine's Day  \
# 90                              False                 False
# 91                              False                 False
# 92                              False                 False
#
#    Event_Veterans Day DayCategory_Event DayCategory_Federal Holiday
# 90              False              True                       False
# 91              False              True                       False
# 92              False              True                       False
#
# [3 rows x 45 columns]
# Feature row for Sequential Year 7 (07/2009):
#      Monthly Nominal GDP Index (inMillion$)  \
# 93                            15604.628182
# 94                            15604.628182
# 95                            15604.628182
# 96                            15604.628182
# 97                            15604.628182
# 98                            15604.628182
#
#     Monthly Real GDP Index (inMillion$)         CPI  unemployment rate  \
# 93                         15066.834087  247.476712           8.600758
# 94                         15066.834087  247.476712           8.600758
# 95                         15066.834087  247.476712           8.600758
# 96                         15066.834087  247.476712           8.600758
# 97                         15066.834087  247.476712           8.600758
# 98                         15066.834087  247.476712           8.600758
#
#     CommercialBankInterestRateonCreditCardPlans  \
# 93                                    12.718409
# 94                                    12.718409
# 95                                    12.718409
# 96                                    12.718409
# 97                                    12.718409
# 98                                    12.718409
#
#     Finance Rate on Personal Loans at Commercial Banks, 24 Month Loan  \
# 93                                          10.764091
# 94                                          10.764091
# 95                                          10.764091
# 96                                          10.764091
# 97                                          10.764091
# 98                                          10.764091
#
#     Earnings or wages  in dollars per hour  \
# 93                               23.084015
# 94                               23.084015
# 95                               23.084015
# 96                               23.084015
# 97                               23.084015
# 98                               23.084015
#
#     AdvertisingExpenses (in Thousand Dollars)  \
# 93                                  197.94697
# 94                                  197.94697
# 95                                  197.94697
# 96                                  197.94697
# 97                                  197.94697
# 98                                  197.94697
#
#     Cotton Monthly Price - US cents per Pound(lbs)  Change(in%)  ...  \
# 93                                       99.121667     0.907348  ...
# 94                                       99.121667     0.907348  ...
# 95                                       99.121667     0.907348  ...
# 96                                       99.121667     0.907348  ...
# 97                                       99.121667     0.907348  ...
# 98                                       99.121667     0.907348  ...
#
#     Event_Mother's Day  Event_New Year's Day  Event_New Year's Eve  \
# 93               False                 False                 False
# 94               False                 False                 False
# 95               False                 False                 False
# 96               False                 False                 False
# 97               False                 False                 False
# 98               False                 False                 False
#
#     Event_Presidents' Day  Event_Thanksgiving Day  \
# 93                  False                   False
# 94                  False                   False
# 95                  False                   False
# 96                  False                   False
# 97                  False                   False
# 98                  False                   False
#
#     Event_Thomas Jefferson's Birthday Event_Valentine's Day  \
# 93                              False                 False
# 94                              False                 False
# 95                              False                 False
# 96                              False                 False
# 97                              False                 False
# 98                              False                 False
#
#    Event_Veterans Day DayCategory_Event DayCategory_Federal Holiday
# 93              False             False                        True
# 94              False             False                        True
# 95              False             False                        True
# 96              False             False                        True
# 97              False             False                        True
# 98              False             False                        True
#
# [6 rows x 45 columns]
# Feature row for Sequential Year 8 (08/2009):
#       Monthly Nominal GDP Index (inMillion$)  \
# 99                             15604.628182
# 100                            15604.628182
# 101                            15604.628182
#
#      Monthly Real GDP Index (inMillion$)         CPI  unemployment rate  \
# 99                          15066.834087  247.476712           8.600758
# 100                         15066.834087  247.476712           8.600758
# 101                         15066.834087  247.476712           8.600758
#
#      CommercialBankInterestRateonCreditCardPlans  \
# 99                                     12.718409
# 100                                    12.718409
# 101                                    12.718409
#
#      Finance Rate on Personal Loans at Commercial Banks, 24 Month Loan  \
# 99                                           10.764091
# 100                                          10.764091
# 101                                          10.764091
#
#      Earnings or wages  in dollars per hour  \
# 99                                23.084015
# 100                               23.084015
# 101                               23.084015
#
#      AdvertisingExpenses (in Thousand Dollars)  \
# 99                                   197.94697
# 100                                  197.94697
# 101                                  197.94697
#
#      Cotton Monthly Price - US cents per Pound(lbs)  Change(in%)  ...  \
# 99                                        99.121667     0.907348  ...
# 100                                       99.121667     0.907348  ...
# 101                                       99.121667     0.907348  ...
#
#      Event_Mother's Day  Event_New Year's Day  Event_New Year's Eve  \
# 99                False                 False                 False
# 100               False                 False                 False
# 101               False                 False                 False
#
#      Event_Presidents' Day  Event_Thanksgiving Day  \
# 99                   False                   False
# 100                  False                   False
# 101                  False                   False
#
#      Event_Thomas Jefferson's Birthday Event_Valentine's Day  \
# 99                               False                 False
# 100                              False                 False
# 101                              False                 False
#
#     Event_Veterans Day DayCategory_Event DayCategory_Federal Holiday
# 99               False             False                        True
# 100              False             False                        True
# 101              False             False                        True
#
# [3 rows x 45 columns]
# Feature row for Sequential Year 9 (09/2009):
#       Monthly Nominal GDP Index (inMillion$)  \
# 102                            15604.628182
# 103                            15604.628182
# 104                            15604.628182
#
#      Monthly Real GDP Index (inMillion$)         CPI  unemployment rate  \
# 102                         15066.834087  247.476712           8.600758
# 103                         15066.834087  247.476712           8.600758
# 104                         15066.834087  247.476712           8.600758
#
#      CommercialBankInterestRateonCreditCardPlans  \
# 102                                    12.718409
# 103                                    12.718409
# 104                                    12.718409
#
#      Finance Rate on Personal Loans at Commercial Banks, 24 Month Loan  \
# 102                                          10.764091
# 103                                          10.764091
# 104                                          10.764091
#
#      Earnings or wages  in dollars per hour  \
# 102                               23.084015
# 103                               23.084015
# 104                               23.084015
#
#      AdvertisingExpenses (in Thousand Dollars)  \
# 102                                  197.94697
# 103                                  197.94697
# 104                                  197.94697
#
#      Cotton Monthly Price - US cents per Pound(lbs)  Change(in%)  ...  \
# 102                                       99.121667     0.907348  ...
# 103                                       99.121667     0.907348  ...
# 104                                       99.121667     0.907348  ...
#
#      Event_Mother's Day  Event_New Year's Day  Event_New Year's Eve  \
# 102               False                 False                 False
# 103               False                 False                 False
# 104               False                 False                 False
#
#      Event_Presidents' Day  Event_Thanksgiving Day  \
# 102                  False                   False
# 103                  False                   False
# 104                  False                   False
#
#      Event_Thomas Jefferson's Birthday Event_Valentine's Day  \
# 102                              False                 False
# 103                              False                 False
# 104                              False                 False
#
#     Event_Veterans Day DayCategory_Event DayCategory_Federal Holiday
# 102              False             False                        True
# 103              False             False                        True
# 104              False             False                        True
#
# [3 rows x 45 columns]
# Feature row for Sequential Year 10 (10/2009):
#       Monthly Nominal GDP Index (inMillion$)  \
# 105                            15604.628182
# 106                            15604.628182
# 107                            15604.628182
# 108                            15604.628182
# 109                            15604.628182
# 110                            15604.628182
#
#      Monthly Real GDP Index (inMillion$)         CPI  unemployment rate  \
# 105                         15066.834087  247.476712           8.600758
# 106                         15066.834087  247.476712           8.600758
# 107                         15066.834087  247.476712           8.600758
# 108                         15066.834087  247.476712           8.600758
# 109                         15066.834087  247.476712           8.600758
# 110                         15066.834087  247.476712           8.600758
#
#      CommercialBankInterestRateonCreditCardPlans  \
# 105                                    12.718409
# 106                                    12.718409
# 107                                    12.718409
# 108                                    12.718409
# 109                                    12.718409
# 110                                    12.718409
#
#      Finance Rate on Personal Loans at Commercial Banks, 24 Month Loan  \
# 105                                          10.764091
# 106                                          10.764091
# 107                                          10.764091
# 108                                          10.764091
# 109                                          10.764091
# 110                                          10.764091
#
#      Earnings or wages  in dollars per hour  \
# 105                               23.084015
# 106                               23.084015
# 107                               23.084015
# 108                               23.084015
# 109                               23.084015
# 110                               23.084015
#
#      AdvertisingExpenses (in Thousand Dollars)  \
# 105                                  197.94697
# 106                                  197.94697
# 107                                  197.94697
# 108                                  197.94697
# 109                                  197.94697
# 110                                  197.94697
#
#      Cotton Monthly Price - US cents per Pound(lbs)  Change(in%)  ...  \
# 105                                       99.121667     0.907348  ...
# 106                                       99.121667     0.907348  ...
# 107                                       99.121667     0.907348  ...
# 108                                       99.121667     0.907348  ...
# 109                                       99.121667     0.907348  ...
# 110                                       99.121667     0.907348  ...
#
#      Event_Mother's Day  Event_New Year's Day  Event_New Year's Eve  \
# 105               False                 False                 False
# 106               False                 False                 False
# 107               False                 False                 False
# 108               False                 False                 False
# 109               False                 False                 False
# 110               False                 False                 False
#
#      Event_Presidents' Day  Event_Thanksgiving Day  \
# 105                  False                   False
# 106                  False                   False
# 107                  False                   False
# 108                  False                   False
# 109                  False                   False
# 110                  False                   False
#
#      Event_Thomas Jefferson's Birthday Event_Valentine's Day  \
# 105                              False                 False
# 106                              False                 False
# 107                              False                 False
# 108                              False                 False
# 109                              False                 False
# 110                              False                 False
#
#     Event_Veterans Day DayCategory_Event DayCategory_Federal Holiday
# 105              False             False                        True
# 106              False              True                       False
# 107              False             False                        True
# 108              False              True                       False
# 109              False             False                        True
# 110              False              True                       False
#
# [6 rows x 45 columns]
# Feature row for Sequential Year 11 (11/2009):
#       Monthly Nominal GDP Index (inMillion$)  \
# 111                            15604.628182
# 112                            15604.628182
# 113                            15604.628182
# 114                            15604.628182
# 115                            15604.628182
# 116                            15604.628182
#
#      Monthly Real GDP Index (inMillion$)         CPI  unemployment rate  \
# 111                         15066.834087  247.476712           8.600758
# 112                         15066.834087  247.476712           8.600758
# 113                         15066.834087  247.476712           8.600758
# 114                         15066.834087  247.476712           8.600758
# 115                         15066.834087  247.476712           8.600758
# 116                         15066.834087  247.476712           8.600758
#
#      CommercialBankInterestRateonCreditCardPlans  \
# 111                                    12.718409
# 112                                    12.718409
# 113                                    12.718409
# 114                                    12.718409
# 115                                    12.718409
# 116                                    12.718409
#
#      Finance Rate on Personal Loans at Commercial Banks, 24 Month Loan  \
# 111                                          10.764091
# 112                                          10.764091
# 113                                          10.764091
# 114                                          10.764091
# 115                                          10.764091
# 116                                          10.764091
#
#      Earnings or wages  in dollars per hour  \
# 111                               23.084015
# 112                               23.084015
# 113                               23.084015
# 114                               23.084015
# 115                               23.084015
# 116                               23.084015
#
#      AdvertisingExpenses (in Thousand Dollars)  \
# 111                                  197.94697
# 112                                  197.94697
# 113                                  197.94697
# 114                                  197.94697
# 115                                  197.94697
# 116                                  197.94697
#
#      Cotton Monthly Price - US cents per Pound(lbs)  Change(in%)  ...  \
# 111                                       99.121667     0.907348  ...
# 112                                       99.121667     0.907348  ...
# 113                                       99.121667     0.907348  ...
# 114                                       99.121667     0.907348  ...
# 115                                       99.121667     0.907348  ...
# 116                                       99.121667     0.907348  ...
#
#      Event_Mother's Day  Event_New Year's Day  Event_New Year's Eve  \
# 111               False                 False                 False
# 112               False                 False                 False
# 113               False                 False                 False
# 114               False                 False                 False
# 115               False                 False                 False
# 116               False                 False                 False
#
#      Event_Presidents' Day  Event_Thanksgiving Day  \
# 111                  False                   False
# 112                  False                    True
# 113                  False                   False
# 114                  False                    True
# 115                  False                   False
# 116                  False                    True
#
#      Event_Thomas Jefferson's Birthday Event_Valentine's Day  \
# 111                              False                 False
# 112                              False                 False
# 113                              False                 False
# ...
# 361                                       99.121667     0.907348  ...
# 362                                       99.121667     0.907348  ...
# 363                                       99.121667     0.907348  ...
# 364                                       99.121667     0.907348  ...
# 365                                       99.121667     0.907348  ...
#
#      Event_Mother's Day  Event_New Year's Day  Event_New Year's Eve  \
# 360               False                 False                 False
# 361               False                 False                 False
# 362               False                 False                 False
# 363               False                 False                 False
# 364               False                 False                 False
# 365               False                 False                 False
#
#      Event_Presidents' Day  Event_Thanksgiving Day  \
# 360                  False                   False
# 361                  False                   False
# 362                  False                   False
# 363                  False                   False
# 364                  False                   False
# 365                  False                   False
#
#      Event_Thomas Jefferson's Birthday Event_Valentine's Day  \
# 360                              False                 False
# 361                              False                 False
# 362                              False                 False
# 363                              False                 False
# 364                              False                 False
# 365                              False                 False
#
#     Event_Veterans Day DayCategory_Event DayCategory_Federal Holiday
# 360              False             False                        True
# 361              False              True                       False
# 362              False             False                        True
# 363              False              True                       False
# 364              False             False                        True
# 365              False              True                       False
#
# [6 rows x 45 columns]
# Feature row for Sequential Year 35 (11/2011):
#       Monthly Nominal GDP Index (inMillion$)  \
# 366                            15604.628182
# 367                            15604.628182
# 368                            15604.628182
# 369                            15604.628182
# 370                            15604.628182
# 371                            15604.628182
#
#      Monthly Real GDP Index (inMillion$)         CPI  unemployment rate  \
# 366                         15066.834087  247.476712           8.600758
# 367                         15066.834087  247.476712           8.600758
# 368                         15066.834087  247.476712           8.600758
# 369                         15066.834087  247.476712           8.600758
# 370                         15066.834087  247.476712           8.600758
# 371                         15066.834087  247.476712           8.600758
#
#      CommercialBankInterestRateonCreditCardPlans  \
# 366                                    12.718409
# 367                                    12.718409
# 368                                    12.718409
# 369                                    12.718409
# 370                                    12.718409
# 371                                    12.718409
#
#      Finance Rate on Personal Loans at Commercial Banks, 24 Month Loan  \
# 366                                          10.764091
# 367                                          10.764091
# 368                                          10.764091
# 369                                          10.764091
# 370                                          10.764091
# 371                                          10.764091
#
#      Earnings or wages  in dollars per hour  \
# 366                               23.084015
# 367                               23.084015
# 368                               23.084015
# 369                               23.084015
# 370                               23.084015
# 371                               23.084015
#
#      AdvertisingExpenses (in Thousand Dollars)  \
# 366                                  197.94697
# 367                                  197.94697
# 368                                  197.94697
# 369                                  197.94697
# 370                                  197.94697
# 371                                  197.94697
#
#      Cotton Monthly Price - US cents per Pound(lbs)  Change(in%)  ...  \
# 366                                       99.121667     0.907348  ...
# 367                                       99.121667     0.907348  ...
# 368                                       99.121667     0.907348  ...
# 369                                       99.121667     0.907348  ...
# 370                                       99.121667     0.907348  ...
# 371                                       99.121667     0.907348  ...
#
#      Event_Mother's Day  Event_New Year's Day  Event_New Year's Eve  \
# 366               False                 False                 False
# 367               False                 False                 False
# 368               False                 False                 False
# 369               False                 False                 False
# 370               False                 False                 False
# 371               False                 False                 False
#
#      Event_Presidents' Day  Event_Thanksgiving Day  \
# 366                  False                   False
# 367                  False                    True
# 368                  False                   False
# 369                  False                    True
# 370                  False                   False
# 371                  False                    True
#
#      Event_Thomas Jefferson's Birthday Event_Valentine's Day  \
# 366                              False                 False
# 367                              False                 False
# 368                              False                 False
# 369                              False                 False
# 370                              False                 False
# 371                              False                 False
#
#     Event_Veterans Day DayCategory_Event DayCategory_Federal Holiday
# 366               True             False                        True
# 367              False             False                        True
# 368               True             False                        True
# 369              False             False                        True
# 370               True             False                        True
# 371              False             False                        True
#
# [6 rows x 45 columns]
# Feature row for Sequential Year 36 (12/2011):
#       Monthly Nominal GDP Index (inMillion$)  \
# 372                            15604.628182
# 373                            15604.628182
# 374                            15604.628182
# 375                            15604.628182
# 376                            15604.628182
# 377                            15604.628182
# 378                            15604.628182
# 379                            15604.628182
# 380                            15604.628182
# 381                            15604.628182
# 382                            15604.628182
# 383                            15604.628182
#
#      Monthly Real GDP Index (inMillion$)         CPI  unemployment rate  \
# 372                         15066.834087  247.476712           8.600758
# 373                         15066.834087  247.476712           8.600758
# 374                         15066.834087  247.476712           8.600758
# 375                         15066.834087  247.476712           8.600758
# 376                         15066.834087  247.476712           8.600758
# 377                         15066.834087  247.476712           8.600758
# 378                         15066.834087  247.476712           8.600758
# 379                         15066.834087  247.476712           8.600758
# 380                         15066.834087  247.476712           8.600758
# 381                         15066.834087  247.476712           8.600758
# 382                         15066.834087  247.476712           8.600758
# 383                         15066.834087  247.476712           8.600758
#
#      CommercialBankInterestRateonCreditCardPlans  \
# 372                                    12.718409
# 373                                    12.718409
# 374                                    12.718409
# 375                                    12.718409
# 376                                    12.718409
# 377                                    12.718409
# 378                                    12.718409
# 379                                    12.718409
# 380                                    12.718409
# 381                                    12.718409
# 382                                    12.718409
# 383                                    12.718409
#
#      Finance Rate on Personal Loans at Commercial Banks, 24 Month Loan  \
# 372                                          10.764091
# 373                                          10.764091
# 374                                          10.764091
# 375                                          10.764091
# 376                                          10.764091
# 377                                          10.764091
# 378                                          10.764091
# 379                                          10.764091
# 380                                          10.764091
# 381                                          10.764091
# 382                                          10.764091
# 383                                          10.764091
#
#      Earnings or wages  in dollars per hour  \
# 372                               23.084015
# 373                               23.084015
# 374                               23.084015
# 375                               23.084015
# 376                               23.084015
# 377                               23.084015
# 378                               23.084015
# 379                               23.084015
# 380                               23.084015
# 381                               23.084015
# 382                               23.084015
# 383                               23.084015
#
#      AdvertisingExpenses (in Thousand Dollars)  \
# 372                                  197.94697
# 373                                  197.94697
# 374                                  197.94697
# 375                                  197.94697
# 376                                  197.94697
# 377                                  197.94697
# 378                                  197.94697
# 379                                  197.94697
# 380                                  197.94697
# 381                                  197.94697
# 382                                  197.94697
# 383                                  197.94697
#
#      Cotton Monthly Price - US cents per Pound(lbs)  Change(in%)  ...  \
# 372                                       99.121667     0.907348  ...
# 373                                       99.121667     0.907348  ...
# 374                                       99.121667     0.907348  ...
# 375                                       99.121667     0.907348  ...
# 376                                       99.121667     0.907348  ...
# 377                                       99.121667     0.907348  ...
# 378                                       99.121667     0.907348  ...
# 379                                       99.121667     0.907348  ...
# 380                                       99.121667     0.907348  ...
# 381                                       99.121667     0.907348  ...
# 382                                       99.121667     0.907348  ...
# 383                                       99.121667     0.907348  ...
#
#      Event_Mother's Day  Event_New Year's Day  Event_New Year's Eve  \
# 372               False                 False                 False
# 373               False                 False                 False
# 374               False                 False                 False
# 375               False                 False                  True
# 376               False                 False                 False
# 377               False                 False                 False
# 378               False                 False                 False
# 379               False                 False                  True
# 380               False                 False                 False
# 381               False                 False                 False
# 382               False                 False                 False
# 383               False                 False                  True
#
#      Event_Presidents' Day  Event_Thanksgiving Day  \
# 372                  False                   False
# 373                  False                   False
# 374                  False                   False
# 375                  False                   False
# 376                  False                   False
# 377                  False                   False
# 378                  False                   False
# 379                  False                   False
# 380                  False                   False
# 381                  False                   False
# 382                  False                   False
# 383                  False                   False
#
#      Event_Thomas Jefferson's Birthday Event_Valentine's Day  \
# 372                              False                 False
# 373                              False                 False
# 374                              False                 False
# 375                              False                 False
# 376                              False                 False
# 377                              False                 False
# 378                              False                 False
# 379                              False                 False
# 380                              False                 False
# 381                              False                 False
# 382                              False                 False
# 383                              False                 False
#
#     Event_Veterans Day DayCategory_Event DayCategory_Federal Holiday
# 372              False              True                       False
# 373              False             False                        True
# 374              False             False                        True
# 375              False              True                       False
# 376              False              True                       False
# 377              False             False                        True
# 378              False             False                        True
# 379              False              True                       False
# 380              False              True                       False
# 381              False             False                        True
# 382              False             False                        True
# 383              False              True                       False
#
# [12 rows x 45 columns]
# Saved the updated submission file to submission_updated.csv
